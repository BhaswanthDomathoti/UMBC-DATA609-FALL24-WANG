# %% [markdown]
# <a href="https://colab.research.google.com/github/BhaswanthDomathoti/UMBC-DATA609-FALL24-WANG/blob/main/Assignments/Assignment_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year      Country  GDP per capita (current US$)  \
# 654   2012     Cameroon                   1433.723928
# 3120  2008   San Marino                  77962.143988
# 313   2013     Barbados                  16923.590920
# 2564  2022   Mozambique                    558.298606
# 3382  2004  South Sudan                           NaN
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 654                                    57.792         21032684.0          CMR
# 3120                                      NaN            30700.0          SMR
# 313                                    76.275           276865.0          BRB
# 2564                                      NaN         32969518.0          MOZ
# 3382                                   50.917          7317118.0          SSD
#
#                           Region         Income Group    Lending Type
# 654          Sub-Saharan Africa   Lower middle income           Blend
# 3120       Europe & Central Asia          High income  Not classified
# 313   Latin America & Caribbean           High income  Not classified
# 2564         Sub-Saharan Africa            Low income             IDA
# 3382         Sub-Saharan Africa            Low income             IDA

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year         Country  GDP per capita (current US$)  \
# 3091  2017          Rwanda                    756.547641
# 3902  2011  United Kingdom                  42109.641880
# 1953  2019        Kiribati                   1410.014643
# 1274  2005         Finland                  39054.850442
# 693   2013  Cayman Islands                  75685.357369
#
#       Life expectancy at birth, total (years)
# 3091                                65.941000
# 3902                                80.951220
# 1953                                67.150000
# 1274                                78.817073
# 693                                       NaN

# %%
df_2022 = df[df["Year"] != 2022]
df_2022.shape
# Out:
# (3906, 9)

# %%
df_2022.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df_2022 = df_2022.dropna()
df_2022.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2022.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, GDP per capita (current US$), Life expectancy at birth, total (years), Population, total, Country Code, Region, Income Group, Lending Type]
# Index: []

# %%
df_cleaned = df.drop_duplicates()

print(f"Cleaned shape: {df_cleaned.shape}")
print(df_cleaned.sample(5))
# Out:
# Cleaned shape: (4123, 9)
#       Year  Country  GDP per capita (current US$)  \
# 1838  2018    Italy                  34622.169666
# 1501  2004     Guam                  23590.888027
# 3751  2012  Tunisia                   4233.916254
# 1093  2014  Ecuador                   6374.631486
# 1389  2006  Germany                  36353.880334
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1838                                83.346341         60421760.0          ITA
# 1501                                76.923000           164004.0          GUM
# 3751                                75.550000         11174383.0          TUN
# 1093                                76.622000         15957994.0          ECU
# 1389                                79.131707         82376451.0          DEU
#
#                           Region         Income Group    Lending Type
# 1838       Europe & Central Asia          High income  Not classified
# 1501         East Asia & Pacific          High income  Not classified
# 3751  Middle East & North Africa  Lower middle income            IBRD
# 1093  Latin America & Caribbean   Upper middle income            IBRD
# 1389       Europe & Central Asia          High income  Not classified

# %% [markdown]
# ## HW Question 2
#
# Find out if there is a relationship between wealth and health
#
# Pick any year worth of data and use plotly express to generate a scatter plot with GDP as x and life expectancy as y.

# %%
year_of_interest = 2019

df_2019 = df[df["Year"] == year_of_interest]
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (217, 9)
#       Year                Country  GDP per capita (current US$)  \
# 1022  2019                Denmark                  59592.980689
# 3150  2019  Sao Tome and Principe                   1924.408150
# 1250  2019          Faroe Islands                  63203.744785
# 2295  2019               Malaysia                  11132.102743
# 984   2019                 Cyprus                  29420.000000
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1022                                81.451220          5814422.0          DNK
# 3150                                68.523000           214599.0          STP
# 1250                                82.946341            51681.0          FRO
# 2295                                75.760000         32804020.0          MYS
# 984                                 81.397000          1228836.0          CYP
#
#                      Region         Income Group    Lending Type
# 1022  Europe & Central Asia          High income  Not classified
# 3150    Sub-Saharan Africa   Lower middle income             IDA
# 1250  Europe & Central Asia          High income  Not classified
# 2295    East Asia & Pacific  Upper middle income            IBRD
# 984   Europe & Central Asia          High income  Not classified

# %%
df_2019.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               6
# Life expectancy at birth, total (years)    8
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2019 = df_2019.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (203, 9)
#       Year   Country  GDP per capita (current US$)  \
# 3188  2019   Senegal                   1462.678353
# 2314  2019  Maldives                  11349.859264
# 3853  2019    Uganda                    823.024733
# 566   2019  Bulgaria                   9874.336326
# 3055  2019   Romania                  12957.999114
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3188                                68.526000         16000781.0          SEN
# 2314                                80.116000           504508.0          MDV
# 3853                                62.991000         42949080.0          UGA
# 566                                 75.112195          6975761.0          BGR
# 3055                                75.607317         19371648.0          ROU
#
#                      Region         Income Group Lending Type
# 3188    Sub-Saharan Africa   Lower middle income          IDA
# 2314             South Asia  Upper middle income          IDA
# 3853    Sub-Saharan Africa            Low income          IDA
# 566   Europe & Central Asia  Upper middle income         IBRD
# 3055  Europe & Central Asia          High income         IBRD

# %%
fig = px.scatter(
    df_2019,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    size="Population, total",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="585c97a5-c475-4ec1-9798-8220e7705950" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("585c97a5-c475-4ec1-9798-8220e7705950")) {                    Plotly.newPlot(                        "585c97a5-c475-4ec1-9798-8220e7705950",                        [{"hovertemplate":"Country=Afghanistan\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[37769499.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[497.741429257502],"xaxis":"x","y":[63.565],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Albania\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","size":[2854191.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[5396.2142432843],"xaxis":"x","y":[79.282],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Algeria\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#00cc96","size":[42705368.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[4021.9832660524],"xaxis":"x","y":[76.474],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Angola\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","marker":{"color":"#ab63fa","size":[32353588.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[2191.34776373555],"xaxis":"x","y":[62.448],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Antigua and Barbuda\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"color":"#FFA15A","size":[92117.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[18730.0047966374],"xaxis":"x","y":[78.691],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Argentina\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#19d3f3","size":[44938712.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[9963.67416171662],"xaxis":"x","y":[77.284],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Armenia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#FF6692","size":[2820602.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":[4828.50488626598],"xaxis":"x","y":[75.439],"yaxis":"y"," ...

# %% [markdown]
# ## Compare China, US, India, Russia

# %%
df_4_countries = df_2019[df_2019["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_4_countries.shape)
df_4_countries
# Out:
# (4, 9)
#       Year             Country  GDP per capita (current US$)  \
# 794   2019               China                  10143.860221
# 1706  2019               India                   2050.163800
# 3074  2019  Russian Federation                  11536.258789
# 3929  2019       United States                  65120.394663
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 794                                 77.968000       1.407745e+09          CHN
# 1706                                70.910000       1.383112e+09          IND
# 3074                                73.083902       1.444063e+08          RUS
# 3929                                78.787805       3.283300e+08          USA
#
#                      Region         Income Group    Lending Type
# 794     East Asia & Pacific  Upper middle income            IBRD
# 1706             South Asia  Lower middle income            IBRD
# 3074  Europe & Central Asia  Upper middle income            IBRD
# 3929          North America          High income  Not classified

# %%
fig = px.scatter(
    df_4_countries,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"Wealth vs Health of US, China, Russian federation and India {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600,
    width=1000
)

# Update text position
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=55000,  # X coordinate
    y=71,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7ebf27e9-c7dd-4fcd-aa90-325741a1f352" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ebf27e9-c7dd-4fcd-aa90-325741a1f352")) {                    Plotly.newPlot(                        "7ebf27e9-c7dd-4fcd-aa90-325741a1f352",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#636efa","size":[1407745000.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"China","orientation":"v","showlegend":true,"text":["China"],"x":[10143.8602205959],"xaxis":"x","y":[77.968],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#EF553B","size":[1383112050.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"India","orientation":"v","showlegend":true,"text":["India"],"x":[2050.1638002619],"xaxis":"x","y":[70.91],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","marker":{"color":"#00cc96","size":[144406261.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation"],"x":[11536.2587890625],"xaxis":"x","y":[73.0839024390244],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#ab63fa","size":[328329953.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"United States","orientation":"v","showlegend":true,"text":["United States"],"x":[65120.3946628653],"xaxis":"x","y":[78.7878048780488],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...

# %%
df_quad = df[df["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_quad.shape)
df_quad.sample(5)
# Out:
# (76, 9)
#       Year             Country  GDP per capita (current US$)  \
# 3072  2017  Russian Federation                  10720.332031
# 3932  2022       United States                  76329.582265
# 781   2006               China                   2099.219430
# 780   2005               China                   1753.414192
# 791   2016               China                   8094.390167
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3072                                72.451463       1.444967e+08          RUS
# 3932                                      NaN       3.332876e+08          USA
# 781                                 74.504000       1.311020e+09          CHN
# 780                                 74.111000       1.303720e+09          CHN
# 791                                 77.218000       1.387790e+09          CHN
#
#                      Region         Income Group    Lending Type
# 3072  Europe & Central Asia  Upper middle income            IBRD
# 3932          North America          High income  Not classified
# 781     East Asia & Pacific  Upper middle income            IBRD
# 780     East Asia & Pacific  Upper middle income            IBRD
# 791     East Asia & Pacific  Upper middle income            IBRD

# %%
fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="GDP per capita (current US$)",
    template= 'plotly_dark'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="56a93688-a80e-4723-b90a-b2c86e3c15a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56a93688-a80e-4723-b90a-b2c86e3c15a8")) {                    Plotly.newPlot(                        "56a93688-a80e-4723-b90a-b2c86e3c15a8",                        [{"hovertemplate":"Country=China\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russian Federation\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russian Federation","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=United States\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[41724.6316287624,44123.4070679055,46302.0008800056,48050.2237771135,48570.0459804586,47194.9433547336,48650.6431283336,50065.9665041742,51784.4185738837,53291.1276891406,55123.8497869046,56762.7294515989,57866.7449341091,59907.754260885,62823.309438197,65120.3946628653,63528.6343027508,70219.472454115,76329.5822652029],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width ...

# %% [markdown]
# ## 10/9/20204 Homework Question 1:
#
# for the Quad time series comparison chart above, try to add country name to the end of the line and then remove the color legend.

# %%
for i, d in enumerate(fig.data):
    print(i, d.name)
# Out:
# 0 China
# 1 India
# 2 Russian Federation
# 3 United States

# %%
for i, d in enumerate(fig.data):
    fig.add_scatter(x=[d.x[-1]], y = [d.y[-1]],
                    mode = 'markers+text',
                    text = d.name,
                    textfont = dict(color=d.line.color),
                    textposition='middle right',
                    marker = dict(color = d.line.color, size = 12),
                    legendgroup = d.name,
                    showlegend=False)
fig.update_layout(showlegend=False)
fig.update_layout(
    xaxis=dict(range=[df_quad['Year'].min(), df_quad['Year'].max() + 2])
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8782c153-64ed-4d93-b6d9-2fbe46d4ac68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8782c153-64ed-4d93-b6d9-2fbe46d4ac68")) {                    Plotly.newPlot(                        "8782c153-64ed-4d93-b6d9-2fbe46d4ac68",                        [{"hovertemplate":"Country=China\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russian Federation\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russian Federation","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=United States\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[41724.6316287624,44123.4070679055,46302.0008800056,48050.2237771135,48570.0459804586,47194.9433547336,48650.6431283336,50065.9665041742,51784.4185738837,53291.1276891406,55123.8497869046,56762.7294515989,57866.7449341091,59907.754260885,62823.309438197,65120.3946628653,63528.6343027508,70219.472454115,76329.5822652029],"yaxis":"y","type":"scatter"},{"legendgroup":"China","marker":{"color":"#636efa","size":12},"mode":"markers+text","showlegend":false,"text":"China","textfont":{"color":"#636efa"},"textposition":"middle right","x":[2022],"y":[12720.2163182363],"type":"scatter"},{"legendgroup":"India","marker":{"color":"#EF553B","size":12},"mode":"markers+ ...

# %%
df_group = df.groupby(["Year", "Region"])["Population, total"].sum().reset_index()
df_group.sample(5)
# Out:
#      Year               Region  Population, total
# 68   2013           South Asia       1.731684e+09
# 83   2015  Sub-Saharan Africa        1.008699e+09
# 6    2004  Sub-Saharan Africa        7.465468e+08
# 126  2022  East Asia & Pacific       2.351976e+09
# 33   2008           South Asia       1.612709e+09

# %% [markdown]
# Home work #5
# Pick a few countries of your interest (for example, G7, BRICS, Nordic countries).
# - 1 Create a line chart showing the trend of Life Expectancy over time for comparing those countries.
# - 2 Pick a year from the data of the above few countries and create a scatter plot to compare their GDP per capita and life expectancy. The size of the dots represent the population. This type of scatter plot is called bubble chart.
# - 3 Bonus - compute the average GDP per capita, the average life expectancy, and the total population for each year of all the seven regions (aggregation) and repeat 1 and 2 using the aggregated data for all regions

# %% [markdown]
# ## Question 1:

# %%
import random

# Select 10 random countries
random_countries = random.sample(list(df["Country"].unique()), 10)

# Filter the DataFrame to include only the selected countries
df_random_countries = df[df["Country"].isin(random_countries)]

# Create a line chart showing the trend of Life Expectancy over time
fig = px.line(
    df_random_countries,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Country",
    title="Life Expectancy Trend for 10 Random Countries",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52f69079-9ff6-4ee2-9bc0-13157fb06117" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52f69079-9ff6-4ee2-9bc0-13157fb06117")) {                    Plotly.newPlot(                        "52f69079-9ff6-4ee2-9bc0-13157fb06117",                        [{"hovertemplate":"Country=Cabo Verde\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cabo Verde","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cabo Verde","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[71.999,72.68,72.239,72.835,72.508,73.088,73.499,74.257,74.484,75.059,75.24,74.62,75.742,76.593,75.733,76.004,74.808,74.052,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Cambodia\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cambodia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Cambodia","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[63.552,64.293,65.059,65.731,66.47,67.444,67.712,68.416,68.915,69.304,69.736,69.873,70.224,70.515,70.561,70.692,70.416,69.584,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Congo, Rep.\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Congo, Rep.","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Congo, Rep.","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[56.986,58.126,58.878,59.643,60.426,61.088,61.683,61.992,62.317,62.695,62.95,63.233,63.577,63.76,64.053,62.747,63.785,63.519,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Denmark\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Denmark","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[77.4926829268293,77.8439024390244,78.0951219512195,78.1951219512195,78.4463414634146,78.5975609756098,79.1,79.8,80.0512195121951,80.3,80.7,80.7024390243902,80.8536585365854,81.1024390243903,80.9536585365854,81.4512195121951,81.6024390243903,81.4048780487805,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Finland\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Finland","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Finland","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[78.7146341463415,78.8170731707317,79.2146341463415,79.2634146341464,79.5682926829268,79.719512195122,79.8707317073171,80.4707317073171,80.6268292682927,80.9756097560976,81.1804878048781,81.4804878048781,81.4292682926829,81.6317073170732,81.7341463414634,81.9829268292683,81.9317073170732,81.9341463414634,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Haiti\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haiti","line":{"color":"#19d3f3","dash" ...

# %% [markdown]
# ## Question 2

# %%
year_of_interest = 2019

df_random_countries_year = df_random_countries[df_random_countries["Year"] == year_of_interest]

df_random_countries_year = df_random_countries_year.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])

fig = px.scatter(
    df_random_countries_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for 10 Random Countries in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=70000,  # X coordinate
    y=60,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f69fb81b-01ae-455b-b26e-07f64c410567" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f69fb81b-01ae-455b-b26e-07f64c410567")) {                    Plotly.newPlot(                        "f69fb81b-01ae-455b-b26e-07f64c410567",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cabo Verde","marker":{"color":"#636efa","size":[577030.0],"sizemode":"area","sizeref":508261.23,"symbol":"circle"},"mode":"markers+text","name":"Cabo Verde","orientation":"v","showlegend":true,"text":["Cabo Verde"],"x":[3903.05031683625],"xaxis":"x","y":[76.004],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cambodia","marker":{"color":"#EF553B","size":[16207746.0],"sizemode":"area","sizeref":508261.23,"symbol":"circle"},"mode":"markers+text","name":"Cambodia","orientation":"v","showlegend":true,"text":["Cambodia"],"x":[1671.3854000919],"xaxis":"x","y":[70.692],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Congo, Rep.","marker":{"color":"#00cc96","size":[5570733.0],"sizemode":"area","sizeref":508261.23,"symbol":"circle"},"mode":"markers+text","name":"Congo, Rep.","orientation":"v","showlegend":true,"text":["Congo, Rep."],"x":[2508.9447830009],"xaxis":"x","y":[62.747],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Denmark","marker":{"color":"#ab63fa","size":[5814422.0],"sizemode":"area","sizeref":508261.23,"symbol":"circle"},"mode":"markers+text","name":"Denmark","orientation":"v","showlegend":true,"text":["Denmark"],"x":[59592.9806886454],"xaxis":"x","y":[81.4512195121951],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Finland","marker":{"color":"#FFA15A","size":[5521606.0],"sizemode":"area","sizeref":508261.23,"symbol":"circle"},"mode":"markers+text","name":"Finland","orientation":"v","showlegend":true,"text":["Finland"],"x":[48629.8582283032],"xaxis":"x","y":[81.9829268292683],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haiti","marker":{"color":"#19d3f3","size":[11160438.0],"sizemode":"area","sizeref":508261.23,"symbol":"circle"},"mode":"markers+text","name":"Haiti","orientation":"v","showlegend":true,"text":["Haiti"],"x":[1345.4750547884],"xaxis":"x","y":[64.255],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u00 ...

# %% [markdown]
# ## Question 3 : Bonus

# %%
# Group by Year and Region, calculate average GDP per capita, average life expectancy, and total population
df_region_agg = df.groupby(["Year", "Region"]).agg(
    {
        "GDP per capita (current US$)": "mean",
        "Life expectancy at birth, total (years)": "mean",
        "Population, total": "sum"
    }
).reset_index()

df_region_agg.sample(5)
# Out:
#      Year                      Region  GDP per capita (current US$)  \
# 102  2018               North America                  74140.894910
# 129  2022  Middle East & North Africa                  21168.212528
# 87   2016  Middle East & North Africa                  14366.724553
# 21   2007         East Asia & Pacific                  12550.951619
# 9    2005  Latin America & Caribbean                    8166.280338
#
#      Life expectancy at birth, total (years)  Population, total
# 102                                80.435976       3.639672e+08
# 129                                      NaN       4.932795e+08
# 87                                 74.970427       4.489174e+08
# 21                                 71.532848       2.141253e+09
# 9                                  72.715040       5.567395e+08

# %%
# Create a line chart showing the trend of Life Expectancy over time for all regions
fig = px.line(
    df_region_agg,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Region",
    title="Life Expectancy Trend for All Regions",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f86bcd3c-6901-46f9-ab5b-0fe70b179826" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f86bcd3c-6901-46f9-ab5b-0fe70b179826")) {                    Plotly.newPlot(                        "f86bcd3c-6901-46f9-ab5b-0fe70b179826",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[70.82474605451937,71.03525226480836,71.35182855093257,71.53284791965567,71.55289167862267,71.93134289813486,72.1956987087518,72.4136262553802,72.63352725968436,72.85580703012913,73.06722883787661,73.2169756097561,73.38525538020087,73.59137517934003,73.8483737446198,74.0432230989957,74.14365566714491,73.64341893830704,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[74.8951915742794,74.99792727272728,75.27233303769401,75.49948070953438,75.9008713968958,76.20778137472284,76.45108115299335,76.83067450110866,77.04216097560976,77.25882793791575,77.56068115299334,77.53420044345899,77.83207627494457,77.99858669623062,78.13177738359202,78.39830288248336,77.36474589800444,77.08593215077606,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean \u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.3771243307555,72.71504045211184,72.99729625223081,73.12531290898275,73.37290660321237,73.64340809042237,73.50570969660916,73.93912790005949,74.13676740035693,74.24663176680548,74.42811957168352,74.51728494943485,74.63538548483046,74.5883503866746,74.79783780487804,74.75240731707316,73.94311280487804,72.96878231707316,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.37166666666667,72.64277235772359,72.80688966318235,73.09993147502904,73.40060975609757,73.75654006968641,74.1584761904762,74.24478281068525,74.24767711962834,74.37635423925667,74.45095238095239,74.7327038327526,74.97042740998839,75.34821718931474,75.54567711962834,75.72125783972126,74.67093147502904,74.36790360046457,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fext ...

# %%
# Pick a year from the data and create a scatter plot to compare their GDP per capita and life expectancy.
year_of_interest = 2019
df_region_agg_year = df_region_agg[df_region_agg["Year"] == year_of_interest]

fig = px.scatter(
    df_region_agg_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Region",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for All Regions in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c08af3b6-4626-4fa9-9631-0445e642375a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c08af3b6-4626-4fa9-9631-0445e642375a")) {                    Plotly.newPlot(                        "c08af3b6-4626-4fa9-9631-0445e642375a",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","size":[2330265835.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[17906.003161543427],"xaxis":"x","y":[74.0432230989957],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[920277481.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[35566.32252548241],"xaxis":"x","y":[78.39830288248336],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean \u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","size":[645295804.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[15465.703305292674],"xaxis":"x","y":[74.75240731707316],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","size":[473201775.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[16111.826427618016],"xaxis":"x","y":[75.72125783972126],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","size":[365995094.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[75882.5711787408],"xaxis":"x","y":[80.68319512195124],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=South Asia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","size":[1861598514.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[3286.247982757694],"xaxis":"x","y":[71.38875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Sub-Saharan Africa \u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fext ...

# %% [markdown]
# ## Homework Question 3
#
# Select a year of data. calculate total population of each region and make a pie chart to display the distribution of total population of all regions.

# %%
print(df.shape)
df.sample(10)
# Out:
# (4123, 9)
#       Year                 Country  GDP per capita (current US$)  \
# 1005  2021                 Czechia                  26822.514186
# 100   2009                  Angola                   3123.698898
# 881   2011              Costa Rica                   9137.455101
# 460   2008  Bosnia and Herzegovina                   4846.790941
# 1103  2005        Egypt, Arab Rep.                   1133.105461
# 4102  2021                  Zambia                   1134.713454
# 3425  2009               Sri Lanka                   2053.766451
# 458   2006  Bosnia and Herzegovina                   3170.174783
# 11    2015             Afghanistan                    566.881133
# 3644  2019                Tanzania                   1050.931763
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1005                                77.373171         10505772.0          CZE
# 100                                 55.752000         22507674.0          AGO
# 881                                 79.348000          4679926.0          CRI
# 460                                 76.838000          3943392.0          BIH
# 1103                                68.779000         79075310.0          EGY
# 4102                                61.223000         19473125.0          ZMB
# 3425                                69.187000         20482477.0          LKA
# 458                                 76.247000          4058086.0          BIH
# 11                                  62.659000         33753499.0          AFG
# 3644                                66.989000         59872579.0          TZA
#
#                           Region         Income Group    Lending Type
# 1005       Europe & Central Asia          High income  Not classified
# 100          Sub-Saharan Africa   Lower middle income            IBRD
# 881   Latin America & Caribbean   Upper middle income            IBRD
# 460        Europe & Central Asia  Upper middle income            IBRD
# 1103  Middle East & North Africa  Lower middle income            IBRD
# 4102         Sub-Saharan Africa   Lower middle income             IDA
# 3425                  South Asia  Lower middle income             IDA
# 458        Europe & Central Asia  Upper middle income            IBRD
# 11                    South Asia           Low income             IDA
# 3644         Sub-Saharan Africa   Lower middle income             IDA

# %%
df["Year"].unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
df_filtered = df[df["Year"] == 2010].dropna(subset=["Population, total", "GDP per capita (current US$)", "Region"])
print(df_filtered.shape)
df_filtered.sample(5)
# Out:
# (209, 9)
#       Year                 Country  GDP per capita (current US$)  \
# 462   2010  Bosnia and Herzegovina                   4506.932352
# 2210  2010              Luxembourg                 110885.991379
# 500   2010                  Brazil                  11249.291890
# 1716  2010               Indonesia                   3094.443079
# 3008  2010             Puerto Rico                  26435.748786
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 462                                 77.073000          3811088.0          BIH
# 2210                                80.631707           506953.0          LUX
# 500                                 73.182000        196353492.0          BRA
# 1716                                68.679000        244016173.0          IDN
# 3008                                78.010000          3721525.0          PRI
#
#                           Region         Income Group    Lending Type
# 462        Europe & Central Asia  Upper middle income            IBRD
# 2210       Europe & Central Asia          High income  Not classified
# 500   Latin America & Caribbean   Upper middle income            IBRD
# 1716         East Asia & Pacific  Upper middle income            IBRD
# 3008  Latin America & Caribbean           High income  Not classified

# %%
population_by_region = df_filtered.groupby("Region")["Population, total"].sum().reset_index()

population_by_region
# Out:
#                        Region  Population, total
# 0         East Asia & Pacific       2.162379e+09
# 1       Europe & Central Asia       8.889814e+08
# 2  Latin America & Caribbean        5.886271e+08
# 3  Middle East & North Africa       3.979976e+08
# 4               North America       3.433972e+08
# 5                  South Asia       1.660546e+09
# 6         Sub-Saharan Africa        8.677708e+08

# %%
fig = px.pie(
    population_by_region,
    values='Population, total',
    names='Region',
    title=f"Total Population Distribution by Region in {year_of_interest}",
    labels={'Population, total': 'Total Population'},
    hole=0.3
)
# Update traces to show both number and percentage
fig.update_traces(textinfo='label+value+percent')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0306aeb7-7e2d-4713-9e87-86ef3d02fc3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0306aeb7-7e2d-4713-9e87-86ef3d02fc3c")) {                    Plotly.newPlot(                        "0306aeb7-7e2d-4713-9e87-86ef3d02fc3c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Region=%{label}\u003cbr\u003eTotal Population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[2162378942.0,888981434.0,588627089.0,397997557.0,343397156.0,1660546144.0,867770770.0],"type":"pie","textinfo":"label+value+percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{ ...

# %% [markdown]
# ## Exercise
#
# Calculate average GDP per capita for  each region and make a bar chart.

# %%
gdp_by_region = df_filtered.groupby('Region').agg(
    {
        'GDP per capita (current US$)': 'mean'
    }
).reset_index()

gdp_by_region
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  14068.845158
# 1       Europe & Central Asia                  31303.467052
# 2  Latin America & Caribbean                   12172.214861
# 3  Middle East & North Africa                  15578.718956
# 4               North America                  66029.336876
# 5                  South Asia                   2059.989661
# 6         Sub-Saharan Africa                    2310.375822

# %%
fig = px.bar(
    data_frame=gdp_by_region,
    x='Region',
    color="Region",
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={
        'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)',
        'Region': 'Region'
    },
    text='GDP per capita (current US$)'
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="16de34f5-5f21-442a-8110-ea8e017fba48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16de34f5-5f21-442a-8110-ea8e017fba48")) {                    Plotly.newPlot(                        "16de34f5-5f21-442a-8110-ea8e017fba48",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"text":[14068.84515827713],"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[14068.84515827713],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"text":[31303.467051661613],"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[31303.467051661613],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"text":[12172.214860564287],"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[12172.214860564287],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"text":[15578.718955551416],"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15578.718955551416],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"text":[66029.33687569977],"textposition":"auto","x":["North America"],"xaxis":"x","y":[66029.33687569977],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"text":[2059.9896610305664],"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2059.9896610305664],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"text":[2310.3758224682306],"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2310.3758224682306],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogra ...

# %% [markdown]
# ## 10/09/2024 Homework Question 2
#
# Round the Average GDP for each region to 2 decimal points.
# Sort the bar according to GDP either in ascending order. Currently, it is ordered alphabetically.

# %%
gdp_by_region['GDP per capita (current US$)'] = gdp_by_region['GDP per capita (current US$)'].round(2)

# %%
fig = px.bar(
    data_frame=gdp_by_region,
    x='Region',
    color="Region",
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region (Sorted by GDP)',
    labels={
        'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)',
        'Region': 'Region'
    },
    text='GDP per capita (current US$)'
)

fig.update_layout(
    xaxis={
        "categoryorder": "total ascending"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9590117a-81a8-464b-9d2b-4dd013c2dcc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9590117a-81a8-464b-9d2b-4dd013c2dcc0")) {                    Plotly.newPlot(                        "9590117a-81a8-464b-9d2b-4dd013c2dcc0",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"text":[14068.85],"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[14068.85],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"text":[31303.47],"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[31303.47],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"text":[12172.21],"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[12172.21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"text":[15578.72],"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15578.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"text":[66029.34],"textposition":"auto","x":["North America"],"xaxis":"x","y":[66029.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"text":[2059.99],"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2059.99],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"text":[2310.38],"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2310.38],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039 ...

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
# Short cut to comment out many lines of code:
# First hightlight the code block
# then, hold down CTL, then press +/


# data = {
#     'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
#     'Grade': ['A', 'B', 'A', 'A', 'B'],
#     'Score': [90, 85, 92, 88, 78]
# }

# df = pd.DataFrame(data)

# # Define the aggregate functions to be applied to the 'Score' column
# agg_functions = {
#     'Score': ['mean', 'max']
# }

# # Group by 'Gender' and 'Grade', then apply the aggregate functions
# grouped = df.groupby(['Gender', 'Grade']).aggregate(agg_functions)

# print(grouped)

# %%
df_2018 = df[df["Year"] == 2018]
print(df_2018.shape)
df_2018.sample(5)
# Out:
# (217, 9)
#       Year     Country  GDP per capita (current US$)  \
# 831   2018     Comoros                   1531.337811
# 565   2018    Bulgaria                   9447.655897
# 2351  2018       Malta                  31785.884830
# 1021  2018     Denmark                  61591.928870
# 2218  2018  Luxembourg                 116786.511655
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 831                                 63.912000           776313.0          COM
# 565                                 74.963415          7025037.0          BGR
# 2351                                82.448780           484630.0          MLT
# 1021                                80.953659          5793636.0          DNK
# 2218                                82.295122           607950.0          LUX
#
#                           Region         Income Group    Lending Type
# 831          Sub-Saharan Africa   Lower middle income             IDA
# 565        Europe & Central Asia  Upper middle income            IBRD
# 2351  Middle East & North Africa          High income  Not classified
# 1021       Europe & Central Asia          High income  Not classified
# 2218       Europe & Central Asia          High income  Not classified

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    {
     'Life expectancy at birth, total (years)': ['min', 'mean', q1, "median", q3, 'max'],
     'GDP per capita (current US$)': ['min', 'mean', q1, "median", q3, 'max']
    }
)

df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                                min       mean
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                       \
#                                    q1   median         q3        max
# Region
# East Asia & Pacific         68.461500  72.1625  79.667823  84.934146
# Europe & Central Asia       75.013707  78.6960  81.760976  83.753659
# Latin America & Caribbean   73.127500  74.4680  77.073750  80.614000
# Middle East & North Africa  72.794000  76.0660  79.722000  82.802439
# North America               79.732012  80.8250  81.334451  81.843902
# South Asia                  68.354750  70.9195  73.362250  80.013000
# Sub-Saharan Africa          60.020750  62.3980  65.414500  75.733000
#
#                            GDP per capita (current US$)                \
#                                                     min          mean
# Region
# East Asia & Pacific                         1241.164485  18083.532845
# Europe & Central Asia                        850.666958  36165.933995
# Latin America & Caribbean                   1489.578406  15005.516403
# Middle East & North Africa                   701.714868  16439.887429
# North America                              46548.638411  74140.894910
# South Asia                                   492.090632   3249.655429
# Sub-Saharan Africa                           232.060617   2497.289753
#
#                                                                       \
#                                       q1        median            q3
# Region
# East Asia & Pacific          3249.086977   6598.976695  31792.165412
# Europe & Central Asia        7252.403668  23165.849479  51466.556563
# Latin America & Caribbean    6282.155427   9574.310271  18648.651035
# Middle East & North Africa   3562.330943   5601.467061  25415.846625
# North America               54685.973925  62823.309438  87937.023160
# South Asia                   1505.940531   1968.895112   3632.479161
# Sub-Saharan Africa            729.773250   1178.708534   2288.949504
#
#
#                                       max
# Region
# East Asia & Pacific          84779.453694
# Europe & Central Asia       193968.090133
# Latin America & Caribbean    85231.774254
# Middle East & North Africa   66264.081168
# North America               113050.736882
# South Asia                   11034.723597
# Sub-Saharan Africa           16411.921117

# %%
df_group.to_excel("by_region.xlsx")

# %%
df_group.to_csv("by_region.csv")

# %%
# df_group.rename(columns={"min":"Minimum","max":"Maximum"}, inplace=True)  Alternative

COLUMN_DICT = {
    "min":"Minimum",
    "max":"Maximum",
    "mean": "Average",
    "q1": "1st Quartile",
    "q3": "3rd quartile"
}

df_group = df_group.rename(columns=COLUMN_DICT)
df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                            Minimum    Average
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                           \
#                            1st Quartile   median 3rd quartile    Maximum
# Region
# East Asia & Pacific           68.461500  72.1625    79.667823  84.934146
# Europe & Central Asia         75.013707  78.6960    81.760976  83.753659
# Latin America & Caribbean     73.127500  74.4680    77.073750  80.614000
# Middle East & North Africa    72.794000  76.0660    79.722000  82.802439
# North America                 79.732012  80.8250    81.334451  81.843902
# South Asia                    68.354750  70.9195    73.362250  80.013000
# Sub-Saharan Africa            60.020750  62.3980    65.414500  75.733000
#
#                            GDP per capita (current US$)                \
#                                                 Minimum       Average
# Region
# East Asia & Pacific                         1241.164485  18083.532845
# Europe & Central Asia                        850.666958  36165.933995
# Latin America & Caribbean                   1489.578406  15005.516403
# Middle East & North Africa                   701.714868  16439.887429
# North America                              46548.638411  74140.894910
# South Asia                                   492.090632   3249.655429
# Sub-Saharan Africa                           232.060617   2497.289753
#
#                                                                       \
#                             1st Quartile        median  3rd quartile
# Region
# East Asia & Pacific          3249.086977   6598.976695  31792.165412
# Europe & Central Asia        7252.403668  23165.849479  51466.556563
# Latin America & Caribbean    6282.155427   9574.310271  18648.651035
# Middle East & North Africa   3562.330943   5601.467061  25415.846625
# North America               54685.973925  62823.309438  87937.023160
# South Asia                   1505.940531   1968.895112   3632.479161
# Sub-Saharan Africa            729.773250   1178.708534   2288.949504
#
#
#                                   Maximum
# Region
# East Asia & Pacific          84779.453694
# Europe & Central Asia       193968.090133
# Latin America & Caribbean    85231.774254
# Middle East & North Africa   66264.081168
# North America               113050.736882
# South Asia                   11034.723597
# Sub-Saharan Africa           16411.921117

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    Minimum=('Life expectancy at birth, total (years)', 'min'),
    Average=('Life expectancy at birth, total (years)', 'mean'),
    percentile_25=('Life expectancy at birth, total (years)', q1)
)

df_group
# Out:
#                               Minimum    Average  percentile_25
# Region
# East Asia & Pacific         63.234000  73.848374      68.461500
# Europe & Central Asia       68.796000  78.131777      75.013707
# Latin America & Caribbean   64.019000  74.797838      73.127500
# Middle East & North Africa  63.038000  75.545677      72.794000
# North America               78.639024  80.435976      79.732012
# South Asia                  63.081000  71.088625      68.354750
# Sub-Saharan Africa          52.554000  62.542100      60.020750

# %% [markdown]
# ## 10/09/2024 Homework question 3
#
# Group the dataset by Region and Income Group, calculate the average, min, and max of GDP per Capita & life Expentancy, total, average, min, and max of population, then save the result to Excel.

# %%
df_group = df_2018.groupby(["Region", "Income Group"]).aggregate(
    {
      'GDP per capita (current US$)': ['mean', 'min', 'max'],
      'Life expectancy at birth, total (years)': ['mean', 'min', 'max'],
      'Population, total': ['sum', 'mean', 'min', 'max']
    }
)

df_group
# Out:
#                                                GDP per capita (current US$)  \
#                                                                        mean
# Region                     Income Group
# East Asia & Pacific        High income                         39154.294420
#                            Low income                                   NaN
#                            Lower middle income                  2674.956798
#                            Upper middle income                  7563.624684
# Europe & Central Asia      High income                         52580.598845
#                            Lower middle income                  1714.906971
#                            Upper middle income                  6819.778284
# Latin America & Caribbean  High income                         26563.676272
#                            Lower middle income                  2350.032441
#                            Not classified                               NaN
#                            Upper middle income                  7936.641559
# Middle East & North Africa High income                         36083.783990
#                            Low income                            906.793480
#                            Lower middle income                  4218.960053
#                            Upper middle income                  7000.698904
# North America              High income                         74140.894910
# South Asia                 Low income                            492.090632
#                            Lower middle income                  2411.738200
#                            Upper middle income                 11034.723597
# Sub-Saharan Africa         High income                         16411.921117
#                            Low income                            644.254729
#                            Lower middle income                  1990.412441
#                            Upper middle income                  7960.079428
#
#                                                                              \
#                                                          min            max
# Region                     Income Group
# East Asia & Pacific        High income          10985.874397   84779.453694
#                            Low income                    NaN            NaN
#                            Lower middle income   1241.164485    4189.052191
#                            Upper middle income   3902.661676   16152.389233
# Europe & Central Asia      High income          12494.423579  193968.090133
#                            Lower middle income    850.666958    3096.562500
#                            Upper middle income   4156.957500   11287.354492
# Latin America & Caribbean  High income           6094.909837   85231.774254
#                            Lower middle income   1489.578406    3471.006951
#                            Not classified                NaN            NaN
#                            Upper middle income   4145.862351   12383.149952
# Middle East & North Africa High income          19887.574311   66264.081168
#                            Low income             701.714868    1111.872092
#                            Lower middle income   2531.200079    9225.845155
#                            Upper middle income   3562.330943   11838.298707
# North America              High income          46548.638411  113050.736882
# South Asia                 Low income             492.090632     492.090632
#                            Lower middle income   1161.534350    4360.584735
#                            Upper middle income  11034.723597   11034.723597
# Sub-Saharan Africa         High income          16411.921117   16411.921117
#                            Low income             232.060617     873.554887
#                            Lower middle income    944.417269    4021.445556
#                            Upper middle income   5687.381043   11643.460596
#
#                                                Life expectancy at birth, total (years)  \
#                                                                                   mean
# Region                     Income Group
# East Asia & Pacific        High income                                       80.218726
#                            Low income                                        73.031000
#                            Lower middle income                               69.653846
#                            Upper middle income                               71.211125
# Europe & Central Asia      High income                                       80.441210
#                            Lower middle income                               71.121171
#                            Upper middle income                               74.832544
# Latin America & Caribbean  High income                                       76.408532
#                            Lower middle income                               69.607750
#                            Not classified                                    71.979000
#                            Upper middle income                               74.682474
# Middle East & North Africa High income                                       80.066652
#                            Low income                                        67.360000
#                            Lower middle income                               74.013125
#                            Upper middle income                               73.033667
# North America              High income                                       80.435976
# South Asia                 Low income                                        63.081000
#                            Lower middle income                               70.935833
#                            Upper middle income                               80.013000
# Sub-Saharan Africa         High income                                       72.841463
#                            Low income                                        61.076136
#                            Lower middle income                               62.626789
#                            Upper middle income                               65.932557
#
#                                                                       \
#                                                       min        max
# Region                     Income Group
# East Asia & Pacific        High income          63.234000  84.934146
#                            Low income           73.031000  73.031000
#                            Lower middle income  65.182000  73.976000
#                            Upper middle income  64.212000  78.662000
# Europe & Central Asia      High income          71.886585  83.753659
#                            Lower middle income  70.353000  71.582683
#                            Upper middle income  68.796000  79.184000
# Latin America & Caribbean  High income          68.896000  80.614000
#                            Lower middle income  64.019000  73.850000
#                            Not classified       71.979000  71.979000
#                            Upper middle income  71.793000  79.484000
# Middle East & North Africa High income          77.212000  82.802439
#                            Low income           64.575000  70.145000
#                            Lower middle income  63.038000  79.729000
#                            Upper middle income  71.514000  74.793000
# North America              High income          78.639024  81.843902
# South Asia                 Low income           63.081000  63.081000
#                            Lower middle income  66.482000  75.748000
#                            Upper middle income  80.013000  80.013000
# Sub-Saharan Africa         High income          72.841463  72.841463
#                            Low income           52.825000  67.067000
#                            Lower middle income  52.554000  75.733000
#                            Upper middle income  61.191000  74.416341
#
#                                                Population, total  \
#                                                              sum
# Region                     Income Group
# East Asia & Pacific        High income              2.232846e+08
#                            Low income               2.563815e+07
#                            Lower middle income      2.944339e+08
#                            Upper middle income      1.774453e+09
# Europe & Central Asia      High income              5.207058e+08
#                            Lower middle income      9.302955e+07
#                            Upper middle income      3.036451e+08
# Latin America & Caribbean  High income              3.318206e+07
#                            Lower middle income      3.898441e+07
#                            Not classified           2.982565e+07
#                            Upper middle income      5.376361e+08
# Middle East & North Africa High income              6.669815e+07
#                            Low income               5.012398e+07
#                            Lower middle income      2.966138e+08
#                            Upper middle income      5.163758e+07
# North America              High income              3.639672e+08
# South Asia                 Low income               3.668678e+07
#                            Lower middle income      1.803358e+09
#                            Upper middle income      4.897580e+05
# Sub-Saharan Africa         High income              9.676200e+04
#                            Low income               5.184169e+08
#                            Lower middle income      5.067339e+08
#                            Upper middle income      6.715640e+07
#
#                                                                           \
#                                                         mean         min
# Region                     Income Group
# East Asia & Pacific        High income          1.594890e+07     11924.0
#                            Low income           2.563815e+07  25638149.0
#                            Lower middle income  2.264876e+07    110929.0
#                            Upper middle income  1.971614e+08     10865.0
# Europe & Central Asia      High income          1.370278e+07     32648.0
#                            Lower middle income  2.325739e+07   6322800.0
#                            Upper middle income  1.897782e+07    622227.0
# Latin America & Caribbean  High income          1.843448e+06     30335.0
#                            Lower middle income  9.746102e+06   6572233.0
#                            Not classified       2.982565e+07  29825653.0
#                            Upper middle income  2.829664e+07     70823.0
# Middle East & North Africa High income          8.337268e+06    484630.0
#                            Low income           2.506199e+07  19333463.0
#                            Lower middle income  3.707672e+07   1057198.0
#                            Upper middle income  1.721253e+07   4569087.0
# North America              High income          1.213224e+08     63918.0
# South Asia                 Low income           3.668678e+07  36686784.0
#                            Lower middle income  3.005596e+08    762096.0
#                            Upper middle income  4.897580e+05    489758.0
# Sub-Saharan Africa         High income          9.676200e+04     96762.0
#                            Low income           2.356441e+07   1924955.0
#                            Lower middle income  2.667020e+07    211344.0
#                            Upper middle income  1.119273e+07   1265577.0
#
#
#                                                          max
# Region                     Income Group
# East Asia & Pacific        High income          1.268110e+08
#                            Low income           2.563815e+07
#                            Lower middle income  1.085688e+08
#                            Upper middle income  1.402760e+09
# Europe & Central Asia      High income          8.290578e+07
#                            Lower middle income  4.462252e+07
#                            Upper middle income  1.444779e+08
# Latin America & Caribbean  High income          1.870145e+07
#                            Lower middle income  1.160690e+07
#                            Not classified       2.982565e+07
#                            Upper middle income  2.101666e+08
# Middle East & North Africa High income          3.501813e+07
#                            Low income           3.079051e+07
#                            Lower middle income  1.037408e+08
#                            Upper middle income  4.059070e+07
# North America              High income          3.268382e+08
# South Asia                 Low income           3.668678e+07
#                            Lower middle income  1.369003e+09
#                            Upper middle income  4.897580e+05
# Sub-Saharan Africa         High income          9.676200e+04
#                            Low income           1.111294e+08
#                            Lower middle income  1.983876e+08
#                            Upper middle income  5.733964e+07

# %%
df_group.to_excel("by_region_IncomeGroup.xlsx")
